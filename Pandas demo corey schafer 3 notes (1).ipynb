# %% [markdown]
# # Reading/writing data from diff sources - excel, jason

# %%
import pandas as pd

# %%
df1 = pd.read_csv(r'C:\Users\SACHIN KUMAR\Documents\survery\survey_results_schema.csv')
df = pd.read_csv(r'C:\Users\SACHIN KUMAR\Documents\survery\survey_results_public.csv')

# %%
filt = (df['Country']=='India')
india_df = df.loc[filt]
india_df.head()
# Out:
#      Respondent                              MainBranch Hobbyist   Age  \
# 6             7          I am a developer by profession      Yes   NaN
# 21           22          I am a developer by profession      Yes   NaN
# 57           58          I am a developer by profession      Yes   NaN
# 62           63  I am a student who is learning to code      Yes  21.0
# 147         149          I am a developer by profession      Yes  36.0
#
#     Age1stCode CompFreq   CompTotal  ConvertedComp Country  \
# 6           18  Monthly         NaN            NaN   India
# 21          18  Monthly         NaN            NaN   India
# 57          22      NaN         NaN            NaN   India
# 62          17      NaN         NaN            NaN   India
# 147         31   Yearly  21000000.0       293196.0   India
#
#              CurrencyDesc  ...                  SurveyEase  \
# 6    United States dollar  ...                         NaN
# 21           Indian rupee  ...                        Easy
# ...

# %%
df2 = india_df.to_csv(r'C:\Users\SACHIN KUMAR\Documents\survery\modified.csv')# will create a new csv  file with the above data

# %%
pd.read_csv(r'C:\Users\SACHIN KUMAR\Documents\survery\modified.csv') # all countr== india was saved with another csv and
#pulled here
# Out:
#       Unnamed: 0  Respondent                              MainBranch Hobbyist  \
# 0              6           7          I am a developer by profession      Yes
# 1             21          22          I am a developer by profession      Yes
# 2             57          58          I am a developer by profession      Yes
# 3             62          63  I am a student who is learning to code      Yes
# 4            147         149          I am a developer by profession      Yes
# ...          ...         ...                                     ...      ...
# 8398       64391       54757                                     NaN      Yes
# 8399       64398       55407                                     NaN      Yes
# 8400       64439       62464                                     NaN      Yes
# 8401       64442       62954                                     NaN      Yes
# 8402       64452       64236                                     NaN      Yes
#
# ...

# %%
india_df.to_csv(r'C:\Users\SACHIN KUMAR\Documents\survery\modified.tsv', sep ='\t')
# files saved with space

# %%
# !pip install xlwt # xlwt will write to an older XLS excel format bt if u want to write to a newer xlsx excel formate
# then wil also need toinstall open pi excel.if we want to read xl files then install xlrd
# Out:
# ERROR: Invalid requirement: '#'

# %%
# !pip install xlwt openpyxl xlrd

# %%
india_df.to_excel(r'C:\Users\SACHIN KUMAR\Documents\survery\modified.xlsx')

# %%
test = pd.read_excel(r'C:\Users\SACHIN KUMAR\Documents\survery\modified.xlsx')

# %%
test = pd.read_excel(r'C:\Users\SACHIN KUMAR\Documents\survery\modified.xlsx', index_col = 'Respondent')

# %%
test
# Out:
#             Unnamed: 0                              MainBranch Hobbyist   Age  \
# Respondent
# 7                    6          I am a developer by profession      Yes   NaN
# 22                  21          I am a developer by profession      Yes   NaN
# 58                  57          I am a developer by profession      Yes   NaN
# 63                  62  I am a student who is learning to code      Yes  21.0
# 149                147          I am a developer by profession      Yes  36.0
# ...                ...                                     ...      ...   ...
# 54757            64391                                     NaN      Yes   NaN
# 55407            64398                                     NaN      Yes   NaN
# 62464            64439                                     NaN      Yes   NaN
# 62954            64442                                     NaN      Yes   NaN
# 64236            64452                                     NaN      Yes   NaN
#
# ...

# %%
india_df.to_json(r'C:\Users\SACHIN KUMAR\Documents\survery\modified.json')
# created a json file which will have 1 dict and data in it

# %%
india_df.to_json(r'C:\Users\SACHIN KUMAR\Documents\survery\modified.json', orient = 'records', lines= True)
# created a json which will have diff dict and data in it

# %%
test =pd.read_json(r'C:\Users\SACHIN KUMAR\Documents\survery\modified.json', orient = 'records', lines= True)
test.head()
# Out:
#    Respondent                              MainBranch Hobbyist   Age  \
# 0           7          I am a developer by profession      Yes   NaN
# 1          22          I am a developer by profession      Yes   NaN
# 2          58          I am a developer by profession      Yes   NaN
# 3          63  I am a student who is learning to code      Yes  21.0
# 4         149          I am a developer by profession      Yes  36.0
#
#   Age1stCode CompFreq   CompTotal  ConvertedComp Country  \
# 0         18  Monthly         NaN            NaN   India
# 1         18  Monthly         NaN            NaN   India
# 2         22     None         NaN            NaN   India
# 3         17     None         NaN            NaN   India
# 4         31   Yearly  21000000.0       293196.0   India
#
#            CurrencyDesc  ...                  SurveyEase  \
# 0  United States dollar  ...                        None
# 1          Indian rupee  ...                        Easy
# ...
